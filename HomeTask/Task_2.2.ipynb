# %%
from math import sqrt

simple = []
othernum = []
count = 0
for i in range(2, 100):
    if i in range(2,11):
        if i%2 == 0 and i !=2:
            count+=1
        if i%3 == 0 and i !=3:
            count+=1
        if count==0:
            simple.append(i)
#         print("i", i, count)
        count=0
#             print("test",i)
    elif i%2 !=0 and i%3 !=0 and i%4 !=0 and i%5 !=0  and i%6 !=0 and i%7 !=0 and i%8 !=0 and i%9 !=0:
        simple.append(i)
#         print(i)
        
# print(simple)
# print(len(simple))



def Factor(n):
    Ans = []
    for x in range(2, int(sqrt(n)+1)):
        if not (n % x):
            Ans.append([x,n//x])    
    return Ans


def isprime(n):
    print(n)
    d = 2
    while d * d <= n and n % d != 0:
        d += 1
    return d * d > n
 
# n = 8
# waste = []
# lst = list(range(1, n+1))
# for i_1, one  in enumerate(lst):
#     for i_2, two in enumerate(lst):
#         if isprime(one + two) and ((one not in waste) and (two not in waste)):
#             print(one, two)
#             waste.append(one)
#             waste.append(two)
#     return(suma)

# print(Factor(12))

value = 24
res = []
# for i in simple:
#     print("i", i)
#     if not (simple[len(simple)+1-len(simple)] % i):
#             res.append([i,simple[i]//i])
#             print(res)
  

for i in range(2,100):
    if i not in simple:
        othernum.append(i)
#         print(i)

for i in simple:
    for j in othernum:
        if i*j < 100 and і щоб j не розкладалось на прості цифри чи щось таке:
            print(i, "*", j,"=",i*j)
    
# for i in simple:
#     print(isprime(i))
# Out:
# 2 * 4 = 8
# 2 * 6 = 12
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20
# 2 * 12 = 24
# 2 * 14 = 28
# 2 * 15 = 30
# 2 * 16 = 32
# 2 * 18 = 36
# 2 * 20 = 40
# 2 * 21 = 42
# 2 * 22 = 44
# 2 * 24 = 48
# 2 * 25 = 50
# 2 * 26 = 52
# 2 * 27 = 54
# 2 * 28 = 56
# 2 * 30 = 60
# 2 * 32 = 64
# 2 * 33 = 66
# 2 * 34 = 68
# 2 * 35 = 70
# 2 * 36 = 72
# 2 * 38 = 76
# 2 * 39 = 78
# 2 * 40 = 80
# 2 * 42 = 84
# 2 * 44 = 88
# 2 * 45 = 90
# 2 * 46 = 92
# 2 * 48 = 96
# 2 * 49 = 98
# 3 * 4 = 12
# 3 * 6 = 18
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30
# 3 * 12 = 36
# 3 * 14 = 42
# 3 * 15 = 45
# 3 * 16 = 48
# 3 * 18 = 54
# 3 * 20 = 60
# 3 * 21 = 63
# 3 * 22 = 66
# 3 * 24 = 72
# 3 * 25 = 75
# 3 * 26 = 78
# 3 * 27 = 81
# 3 * 28 = 84
# 3 * 30 = 90
# 3 * 32 = 96
# 3 * 33 = 99
# 5 * 4 = 20
# 5 * 6 = 30
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50
# 5 * 12 = 60
# 5 * 14 = 70
# 5 * 15 = 75
# 5 * 16 = 80
# 5 * 18 = 90
# 7 * 4 = 28
# 7 * 6 = 42
# 7 * 8 = 56
# 7 * 9 = 63
# 7 * 10 = 70
# 7 * 12 = 84
# 7 * 14 = 98
# 11 * 4 = 44
# ...
